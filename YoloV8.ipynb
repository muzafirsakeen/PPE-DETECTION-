# %%
cd /content/drive/MyDrive/dataset/X
# Out:
# /content/drive/MyDrive/dataset/X

# %%
ls
# Out:
# classes.txt  data_custom.yaml  download_images.py  train/  Untitled.ipynb  val/

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/dataset/X

# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.62 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# Traing the model with custom dataset

# %%
# %cd {HOME}
# !yolo task=detect mode=train epochs =100 data =/content/drive/MyDrive/dataset/X/data_custom.yaml model=yolov8m.pt imgsz=640 batch=8
# Out:
# /content/drive/MyDrive/dataset/X
# Ultralytics YOLOv8.0.62 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# ...

# %% [markdown]
# To detect image

# %%
# !yolo task=detect mode=predict model=yolov8m_custom.pt show=True conf=0.5 source = 1.jpg save_txt=True save=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# 2023-04-05 17:09:20.926019: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 17:09:22.120172: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.62 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/X/1.jpg: 448x640 1 hard_hat, 1 goggles, 2 glovess, 1317.3ms
# Speed: 2.6ms preprocess, 1317.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
# 1 label saved to runs/detect/predict4/labels

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict4/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
import cv2
# !yolo task=detect mode=predict model=yolov8m_custom.pt show=True conf=0.5 source = 1.jpg save_txt=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# 2023-04-05 16:47:03.322435: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 16:47:04.810980: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.62 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/X/1.jpg: 448x640 1 hard_hat, 1 goggles, 2 glovess, 1314.7ms
# Speed: 2.8ms preprocess, 1314.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels

# %%
# !yolo task=detect mode=predict model=yolov8m_custom.pt show=True conf=0.5 source = 1.jpg save_txt=True save_crop=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# 2023-04-05 16:48:45.721869: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 16:48:47.491097: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.62 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/X/1.jpg: 448x640 1 hard_hat, 1 goggles, 2 glovess, 1061.4ms
# Speed: 2.3ms preprocess, 1061.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 1 label saved to runs/detect/predict2/labels

# %%
# !yolo task=detect mode=predict model=yolov8m_custom.pt show=True conf=0.5 source =/content/drive/MyDrive/dataset/X/Construction_Safety.mp4 save_txt=True save_crop=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# 2023-04-05 17:07:28.608332: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/tensorboard/compat/__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.9/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
# ...
